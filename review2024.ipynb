# %%
print("welcome you gat this")
# Out:
# welcome you gat this

# %%
type("welcome")
# Out:
# str

# %%
"HELLO WORLD".lower()
# Out:
# 'hello world'

# %%
"Hello world".lower()
# Out:
# 'hello world'

# %%
print("GET BUSY SEGUN")
# Out:
# GET BUSY SEGUN

# %%
print("GET BUSY SEGUN")
# Out:
# GET BUSY SEGUN

# %%
type("GET BUSY SEGUN")
# Out:
# str

# %%
#GET BUSY SEGUN

# %%
days= ("mon", "tues", "wed", "thurs","fri")

# %%
days
# Out:
# ('mon', 'tues', 'wed', 'thurs', 'fri')

# %%
day1={"mon", "tues", "wed", 'thurs",'
      "fri"}

# %%
day2=["mon", "tues", "wed", "thurs",f"ri"]

# %%
day1
# Out:
# {'mon', 'thurs",fri', 'tues', 'wed'}

# %%
#day2.append("weekend")
day2
# Out:
# ['mon', 'tues', 'wed', 'thurs', 'ri']

# %%
#days.append("red")
#days.append()
type(day1)
# Out:
# set

# %%
days[2]
# Out:
# 'wed'

# %%
day1.append("weekend")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10372/1206594867.py in <module>
# ----> 1 day1.append("weekend")
#
# AttributeError: 'set' object has no attribute 'append'

# %%
"mon" in day1
# Out:
# True

# %% [markdown]
# "fri" in day2 and "mon" in days

# %%
"fri" in day2 and "mon" in days
# Out:
# False

# %% [markdown]
# #if, else statement

# %%
if "wed" in days:
    print ("mon is labour day!!, yay!!")
# Out:
# mon is labour day!!, yay!!

# %%
if "mon" in day1:
    print("labour day")
else:
        print("i dey study")
# Out:
# labour day

# %%
if "mon" not in day1:
    print("labour day")
elif "fues" in day1:
        print("i dey study")
else: print("am here")
# Out:
# am here

# %%
print("its 8pm") if "fri" in day2 else print("God help me")
# Out:
# God help me

# %%
print("hp laptop") if "ri" in days else print("my nane is segun")
# Out:
# my nane is segun

# %% [raw]
# if "birthdays" in days:
#     print("date")
# else:
#     print("i am blessed")

# %%
print("i shall get my data analyst job") if "mon" in days else print("it is well")
# Out:
# i shall get my data analyst job

# %%
for item in days:
    print(item)
# Out:
# mon
# tues
# wed
# thurs
# fri

# %%
for item in days:
    print(f"days of week = {item}")
# Out:
# days of week = mon
# days of week = tues
# days of week = wed
# days of week = thurs
# days of week = fri

# %%
for i in enumerate(days):
    print(i)
# Out:
# (0, 'mon')
# (1, 'tues')
# (2, 'wed')
# (3, 'thurs')
# (4, 'fri')

# %%
if "mon " in days:
    print("hello")
else:
    print("we good")
# Out:
# we good

# %%
#dir(len)

# %%
help("index")
# Out:
# No Python documentation found for 'index'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
def segun():
    print("omo ologo")
    print("it is well with my soul")

# %%
segun()
# Out:
# omo ologo
# it is well with my soul

# %%
def today():
    return "it is well"

# %%
def nig_temp(f):
    c = (5/9 * (f-32))
    return (c)

# %%
temps=[72,74,81,84,76,80,67]

# %%
nig_temp(72)
# Out:
# 22.22222222222222

# %%
round(22.2222,2)
# Out:
# 22.22

# %%
#7 _days nig temperature
for temp in temps:
   wdays_c=(nig_temp(temp))
   wdays_c=(round(wdays_c,2))
   print(wdays_c)
# Out:
# 22.22
# 23.33
# 27.22
# 28.89
# 24.44
# 26.67
# 19.44

# %% [markdown]
# ####

# %%
# convert lb to kg
def weight_conv(lb):
    kg=((1/2.204)*lb)
    return (kg)

# %%
weight_conv(158)
# Out:
# 71.68784029038112

# %%
weight=(100,205,84,150,400,102)

# %%
for w in weight:
    print(w)
# Out:
# 100
# 205
# 84
# 150
# 400
# 102

# %%
[w for w in weight]
# Out:
# [100, 205, 84, 150, 400, 102]

# %%
[w for w in weight if w<= 150]
# Out:
# [100, 84, 150, 102]

# %%
#map, filter and reduce
min([w for w in weight ])
# Out:
# 84

# %%
# weight in kg
for w in weight:
    kg_w=(weight_conv(w))
    kg_w=round(kg_w,2)
    print(kg_w)
# Out:
# 45.37
# 93.01
# 38.11
# 68.06
# 181.49
# 46.28

# %%
temps
# Out:
# [72, 74, 81, 84, 76, 80, 67]

# %%
temps[-1]= 70

# %%
temps
# Out:
# [72, 74, 81, 84, 76, 80, 70]

# %%
from datetime import date

# %%
date=date.today()

# %%
today = str(date.today())
print(today)
# Out:
# 2024-09-16

# %%
date1= today.split("-")

# %%
date1
# Out:
# ['2024', '09', '16']

# %%
yr=date1[0]

# %%
mm= date1[1]
dd= date1[2]

# %%
dd
# Out:
# '16'

# %%
print(mm,dd,yr)
# Out:
# 09 16 2024

# %%
n_date=[mm,dd,yr]

# %%
merge="/".join(n_date)

# %%
merge
# Out:
# '09/16/2024'

# %%
temps
# Out:
# [72, 74, 81, 84, 76, 80, 70]

# %%
temps.insert(3, 100)

# %%
temps
# Out:
# [72, 74, 81, 100, 84, 76, 80, 70]

# %%
temps.add(200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10372/2094817266.py in <module>
# ----> 1 temps.add(200)
#
# AttributeError: 'list' object has no attribute 'add'

# %% [markdown]
# temps.sort()

# %% [raw]
# temps.sort()

# %%
temps
# Out:
# [72, 74, 81, 100, 84, 76, 80, 70]

# %%
import requests as r

# %%
news=r.get("https://www.msn.com/en-us/news/politics/trump-harris-debate-key-takeaways-from-tuesdays-presidential-debate/ar-AA1qktIR?ocid=BingNewsSerp")

# %%
news
# Out:
# <Response [200]>

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 9, 16, 10, 7, 48, 824047)

# %%
date.today()
# Out:
# datetime.date(2024, 9, 16)

# %%
dob=datetime(1979, 4,22)

# %%
dob
# Out:
# datetime.datetime(1979, 4, 22, 0, 0)

# %%
((datetime.now())- dob).days/365
# Out:
# 45.43561643835616

# %%
#import data and exploration

# %% [raw]
# #import numpy

# %%
import flask

# %%
import scipy

# %%
import pandas as pd

# %%
meningitis=pd.read_csv("meningitis_dataset.csv")

# %%
pd.read_csv("Ebola_Cases.csv")
# Out:
#      Unnamed: 0        Date  Day   Count Status Country
# 0             0  2015-01-05  289  2776.0  Cases  Guinea
# 1             1  2015-01-04  288  2775.0  Cases  Guinea
# 2             2  2015-01-03  287  2769.0  Cases  Guinea
# 3             3  2015-01-02  286     0.0  Cases  Guinea
# 4             4  2014-12-31  284  2730.0  Cases  Guinea
# ..          ...         ...  ...     ...    ...     ...
# 971         971  2014-03-27    5     0.0  Cases    Mali
# 972         972  2014-03-26    4     0.0  Cases    Mali
# 973         973  2014-03-25    3     0.0  Cases    Mali
# 974         974  2014-03-24    2     0.0  Cases    Mali
# 975         975  2014-03-22    0     0.0  Cases    Mali
#
# [976 rows x 6 columns]

# %% [markdown]
# ### web scrapping

# %%
mpox=pd.read_html("https://en.wikipedia.org/wiki/Mpox")

# %%
len(mpox)
# Out:
# 26

# %%
mpox[2]
# Out:
#           Year                                            Country  \
# 0         1970                   Democratic Republic of the Congo
# 1         1971                                            Nigeria
# 2    1981–1986                   Democratic Republic of the Congo
# 3    1995–1996                   Democratic Republic of the Congo
# 4    2001–2004                   Democratic Republic of the Congo
# 5         2003                                      United States
# 6         2015                       Central African Republic[85]
# 7    2017–2022                                            Nigeria
# 8         2020               Democratic Republic of the Congo[86]
# 9    2022–2023                                    Global outbreak
# 10  2023–2024*  Democratic Republic of the Congo Central Afric...
#
#               Clade Human cases Human deaths Case fatality rate         Notes
# 0           Clade I           5      no data                NaN           NaN
# ...

# %%
table=pd.read_html("https://en.wikipedia.org/wiki/2022%E2%80%932023_mpox_outbreak_in_the_United_States")

# %%
len(table)
# Out:
# 12

# %%
table [0]
# Out:
#          2022–2024 mpox outbreak in the United States  \
# 0   Spread of mpox by US state as of September 24,...
# 1                                             Disease
# 2                                        Virus strain
# 3                                            Location
# 4                                          Index case
# 5                                        Arrival date
# 6                                                Date
# 7                                     Confirmed cases
# 8                                              Deaths
# 9                                  Government website
# 10           www.cdc.gov/poxvirus/mpox/response/2022/
#
#        2022–2024 mpox outbreak in the United States.1
# 0   Spread of mpox by US state as of September 24,...
# 1                                                Mpox
# 2                Monkeypox virus (West African clade)
# 3                                       United States
# ...

# %%
new_t=table[0]

# %%
#using .loc to rearrage
rearrange_table=new_t.loc[1:10, ["2022–2024 mpox outbreak in the United States.1","2022–2024 mpox outbreak in the United States"]]

# %%
rearrange_table
# Out:
#        2022–2024 mpox outbreak in the United States.1  \
# 1                                                Mpox
# 2                Monkeypox virus (West African clade)
# 3                                       United States
# 4                            Boston, Massachusetts[1]
# 5   May 17, 2022 (2 years, 3 months, 4 weeks and 1...
# 6                               as of August 31, 2024
# 7                                           33,590[2]
# 8                                               60[2]
# 9                                  Government website
# 10           www.cdc.gov/poxvirus/mpox/response/2022/
#
#    2022–2024 mpox outbreak in the United States
# 1                                       Disease
# 2                                  Virus strain
# 3                                      Location
# 4                                    Index case
# 5                                  Arrival date
# 6                                          Date
# ...

# %%
#meningitis.iloc[:5,1:8]
meningitis.loc[:10,["firstname", "surname", "gender", "state"]]
# Out:
#     firstname    surname  gender    state
# 0       Grace     Solade  Female   Rivers
# 1        Kure     Eneche    Male   Ebonyi
# 2      Adaugo     Sanusi  Female     Ogun
# 3   Mooslemat     Sowore  Female     Ondo
# 4       Yusuf  Abdusalam    Male      Oyo
# 5       Janet     Yakubu  Female   Kaduna
# 6      Adaugo      Razak  Female   Taraba
# 7   Danmbazzu    Annakyi    Male  Katsina
# 8        Iyin    Adejoro    Male  Katsina
# 9      Adaugo     Okorie  Female     Osun
# 10     Adijah  Muhammadu  Female    Niger

# %%
meningitis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284484 entries, 0 to 284483
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          284484 non-null  int64
#  1   surname                     284484 non-null  object
#  2   firstname                   284484 non-null  object
#  3   middlename                  284484 non-null  object
#  4   gender                      284484 non-null  object
#  5   gender_male                 284484 non-null  int64
#  6   gender_female               284484 non-null  int64
#  7   state                       284484 non-null  object
#  8   settlement                  284484 non-null  object
#  9   rural_settlement            284484 non-null  int64
#  10  urban_settlement            284484 non-null  int64
#  11  report_date                 284484 non-null  object
#  12  report_year                 284484 non-null  int64
# ...

# %%
Ebola_lag=meningitis.loc[(meningitis["state"]=="Lagos")  & (meningitis["age"]<=40)  & (meningitis["disease"]=="Ebola")& (meningitis["gender"]=="Female"), ["surname","firstname", "gender", "state","age","disease"]]

# %%
Ebola_lag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 4644 to 284261
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   surname    234 non-null    object
#  1   firstname  234 non-null    object
#  2   gender     234 non-null    object
#  3   state      234 non-null    object
#  4   age        234 non-null    int64
#  5   disease    234 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 12.8+ KB

# %%
meningitis2=meningitis.loc[meningitis["age"]>=40,[ "surname","firstname", "gender", "age","state"]]

# %%
meningitis2
# Out:
#          surname  firstname  gender  age        state
# 3         Sowore  Mooslemat  Female   63         Ondo
# 5         Yakubu      Janet  Female   44       Kaduna
# 6          Razak     Adaugo  Female   61       Taraba
# 8        Adejoro       Iyin    Male   54      Katsina
# 11      Okerewke       Kure    Male   50  Cross River
# ...          ...        ...     ...  ...          ...
# 284475    Bukola     Sunday    Male   45        Borno
# 284476  Akintola      Debby  Female   69       Taraba
# 284477     Gombi     Zainab  Female   42         Ondo
# 284479   Mukthar     Alimat  Female   67  Cross River
# 284480   Akenzua    Deborah  Female   64        Kwara
#
# [122638 rows x 5 columns]

# %%
new_t.iloc[1:10,:]
# Out:
#   2022–2024 mpox outbreak in the United States  \
# 1                                      Disease
# 2                                 Virus strain
# 3                                     Location
# 4                                   Index case
# 5                                 Arrival date
# 6                                         Date
# 7                              Confirmed cases
# 8                                       Deaths
# 9                           Government website
#
#       2022–2024 mpox outbreak in the United States.1
# 1                                               Mpox
# 2               Monkeypox virus (West African clade)
# 3                                      United States
# 4                           Boston, Massachusetts[1]
# 5  May 17, 2022 (2 years, 3 months, 4 weeks and 1...
# 6                              as of August 31, 2024
# 7                                          33,590[2]
# 8                                              60[2]
# ...

# %%
#csv_file.info()
#csv_file.head()
#csv_file.tail()
#csv_file.shape
#csv_file.columns

# %%
#sqlalchemy
from sqlalchemy import create_engine
import pandas as pd

# %%
rdbms = 'postgresql'
server = 'djynnius.com'
username = 'admin' 
password = '3ikakkeMuSigmaPassword'
database = 'musigma'
port = 5444

engine = create_engine(f"{rdbms}://{username}:{password}@{server}:{port}/{database}")

# %%
#pd.read_sql("SELECT * FROM nhanes limit 10", engine)

# %%
#meningitis

# %%
#!pip install pandasql

# %%
from pandasql import sqldf as sql

# %%
#SQL
query = '''
SELECT 
  Gender, 
  COUNT(Gender)
FROM nhanes 
GROUP BY Gender
'''
#sql(query)

# %%
#SQL
query = '''    
    SELECT  * 
    FROM meningitis
    limit 10 '''

sql(query)
# Out:
#    id    surname  firstname  middlename  gender  gender_male  gender_female  \
# 0   1     Solade      Grace      Solape  Female            0              1
# 1   2     Eneche       Kure     Balogun    Male            1              0
# 2   3     Sanusi     Adaugo    Katerine  Female            0              1
# 3   4     Sowore  Mooslemat     Ifedayo  Female            0              1
# 4   5  Abdusalam      Yusuf      Okafor    Male            1              0
# 5   6     Yakubu      Janet      Chioma  Female            0              1
# 6   7      Razak     Adaugo      Adaobi  Female            0              1
# 7   8    Annakyi  Danmbazzu      Osagie    Male            1              0
# 8   9    Adejoro       Iyin  Osatimehin    Male            1              0
# 9  10     Okorie     Adaugo       Chika  Female            0              1
#
#      state settlement  rural_settlement  ...  NmA NmC  NmW  health_status  \
# ...

# %%
# Out:
#   File "C:\Users\segun\AppData\Local\Temp/ipykernel_10372/1802949244.py", line 3
#     FROM meningitis
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###### table[5]

# %%
mpox_usa=table[6]

# %%
mpox_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      54 non-null     object
#  1   Cases      54 non-null     object
#  2   Change[b]  54 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %%
mpox_usa
# Out:
#                                    State  \
# 0                                Alabama
# 1                                 Alaska
# 2                                Arizona
# 3                               Arkansas
# 4                             California
# 5                               Colorado
# 6                            Connecticut
# 7                               Delaware
# 8                   District of Columbia
# 9                                Florida
# 10                               Georgia
# 11                                Hawaii
# 12                                 Idaho
# 13                              Illinois
# 14                               Indiana
# 15                                  Iowa
# 16                                Kansas
# 17                              Kentucky
# 18                             Louisiana
# 19                                 Maine
# 20                              Maryland
# 21                         Massachusetts
# ...

# %%
#mpox_usa.isna().sum()
mpox_usa.isnull().sum()
# Out:
# State        0
# Cases        0
# Change[b]    0
# dtype: int64

# %%
#mpox_usa.drop("Change[b]")

# %%
mpox_usa.dropna(thresh=1)
# Out:
#                                    State  \
# 0                                Alabama
# 1                                 Alaska
# 2                                Arizona
# 3                               Arkansas
# 4                             California
# 5                               Colorado
# 6                            Connecticut
# 7                               Delaware
# 8                   District of Columbia
# 9                                Florida
# 10                               Georgia
# 11                                Hawaii
# 12                                 Idaho
# 13                              Illinois
# 14                               Indiana
# 15                                  Iowa
# 16                                Kansas
# 17                              Kentucky
# 18                             Louisiana
# 19                                 Maine
# 20                              Maryland
# 21                         Massachusetts
# ...

# %%
mpox_usa.columns
# Out:
# Index(['State', 'Cases', 'Change[b]'], dtype='object')

# %%
mpox_usa1=mpox_usa[['State', 'Cases']]

# %%
mpox_usa1
# Out:
#                                    State                                 Cases
# 0                                Alabama                                   186
# 1                                 Alaska                                     5
# 2                                Arizona                                   580
# 3                               Arkansas                                    72
# 4                             California                                  5670
# 5                               Colorado                                   407
# 6                            Connecticut                                   144
# 7                               Delaware                                    43
# 8                   District of Columbia                                   525
# 9                                Florida                                  2855
# 10                               Georgia                                  1984
# ...

# %%
mpox_usa1=mpox_usa1.drop([52], axis=0)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
mpox_usa1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   52 non-null     object
#  1   Cases   52 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
#mpox_usa["Change[b]"]=mpox_usa["Change[b]"].fillna("")

# %%
mpox_usa1
# Out:
#                    State Cases
# 0                Alabama   186
# 1                 Alaska     5
# 2                Arizona   580
# 3               Arkansas    72
# 4             California  5670
# 5               Colorado   407
# 6            Connecticut   144
# 7               Delaware    43
# 8   District of Columbia   525
# 9                Florida  2855
# 10               Georgia  1984
# 11                Hawaii    35
# 12                 Idaho    16
# 13              Illinois  1422
# 14               Indiana   285
# 15                  Iowa    29
# 16                Kansas    47
# 17              Kentucky    97
# 18             Louisiana   306
# 19                 Maine    13
# 20              Maryland   739
# 21         Massachusetts   456
# 22              Michigan   395
# 23             Minnesota   234
# 24           Mississippi   108
# 25              Missouri   209
# 26               Montana     7
# 27              Nebraska    31
# 28                Nevada   319
# ...

# %%
#convert to int
mpox_usa1["Cases"]=pd.to_numeric(mpox_usa1["Cases"])

# %%
sns.histplot(x="Cases", data=mpox_usa1)
plt.figure(figsize=(12,4))
plt.show()

# %%
mpox_usa1["Cases"].describe()
# Out:
# count      52.000000
# mean      572.730769
# std      1088.108669
# min         3.000000
# 25%        41.000000
# 50%       203.500000
# 75%       534.750000
# max      5670.000000
# Name: Cases, dtype: float64

# %%
sns.boxplot(x="Cases", data=mpox_usa1)
plt.show()
#sns.set(rc={'figure.figsize':(200, 5)})

# %%
#mpox_usa1["State"].value_counts()

# %%
mpox_usa.shape
# Out:
# (54, 3)

# %%
max(mpox_usa1["Cases"])
# Out:
# 5670

# %%
#2022-2024 mpox outbreake in usa by state
mpox_usa
# Out:
#                                    State  \
# 0                                Alabama
# 1                                 Alaska
# 2                                Arizona
# 3                               Arkansas
# 4                             California
# 5                               Colorado
# 6                            Connecticut
# 7                               Delaware
# 8                   District of Columbia
# 9                                Florida
# 10                               Georgia
# 11                                Hawaii
# 12                                 Idaho
# 13                              Illinois
# 14                               Indiana
# 15                                  Iowa
# 16                                Kansas
# 17                              Kentucky
# 18                             Louisiana
# 19                                 Maine
# 20                              Maryland
# 21                         Massachusetts
# ...

# %%
meningitis.head(10)
# Out:
#    id    surname  firstname  middlename  gender  gender_male  gender_female  \
# 0   1     Solade      Grace      Solape  Female            0              1
# 1   2     Eneche       Kure     Balogun    Male            1              0
# 2   3     Sanusi     Adaugo    Katerine  Female            0              1
# 3   4     Sowore  Mooslemat     Ifedayo  Female            0              1
# 4   5  Abdusalam      Yusuf      Okafor    Male            1              0
# 5   6     Yakubu      Janet      Chioma  Female            0              1
# 6   7      Razak     Adaugo      Adaobi  Female            0              1
# 7   8    Annakyi  Danmbazzu      Osagie    Male            1              0
# 8   9    Adejoro       Iyin  Osatimehin    Male            1              0
# 9  10     Okorie     Adaugo       Chika  Female            0              1
#
#      state settlement  rural_settlement  ...  NmA NmC  NmW  health_status  \
# ...

# %%
meningitis.info()
#meningitis["gender"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284484 entries, 0 to 284483
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          284484 non-null  int64
#  1   surname                     284484 non-null  object
#  2   firstname                   284484 non-null  object
#  3   middlename                  284484 non-null  object
#  4   gender                      284484 non-null  object
#  5   gender_male                 284484 non-null  int64
#  6   gender_female               284484 non-null  int64
#  7   state                       284484 non-null  object
#  8   settlement                  284484 non-null  object
#  9   rural_settlement            284484 non-null  int64
#  10  urban_settlement            284484 non-null  int64
#  11  report_date                 284484 non-null  object
#  12  report_year                 284484 non-null  int64
# ...

# %%
meningitis.columns
# Out:
# Index(['id', 'surname', 'firstname', 'middlename', 'gender', 'gender_male',
#        'gender_female', 'state', 'settlement', 'rural_settlement',
#        'urban_settlement', 'report_date', 'report_year', 'age', 'age_str',
#        'date_of_birth', 'child_group', 'adult_group', 'disease', 'cholera',
#        'diarrhoea', 'measles', 'viral_haemmorrhaphic_fever', 'meningitis',
#        'ebola', 'marburg_virus', 'yellow_fever', 'rubella_mars', 'malaria',
#        'serotype', 'NmA', 'NmC', 'NmW', 'health_status', 'alive', 'dead',
#        'report_outcome', 'unconfirmed', 'confirmed', 'null_serotype'],
#       dtype='object')

# %%
meningitis.head()
# Out:
#    id    surname  firstname middlename  gender  gender_male  gender_female  \
# 0   1     Solade      Grace     Solape  Female            0              1
# 1   2     Eneche       Kure    Balogun    Male            1              0
# 2   3     Sanusi     Adaugo   Katerine  Female            0              1
# 3   4     Sowore  Mooslemat    Ifedayo  Female            0              1
# 4   5  Abdusalam      Yusuf     Okafor    Male            1              0
#
#     state settlement  rural_settlement  ...  NmA NmC  NmW  health_status  \
# 0  Rivers      Rural                 1  ...    0   0    0          alive
# 1  Ebonyi      Rural                 1  ...    0   0    1          Alive
# 2    Ogun      Urban                 0  ...    0   0    1           Dead
# 3    Ondo      Rural                 1  ...    0   0    1          Alive
# 4     Oyo      Urban                 0  ...    0   0    1          Alive
#
#   alive dead  report_outcome  unconfirmed confirmed  null_serotype
# ...

# %%
meningitis1=meningitis[['id', 'surname', 'firstname', 'middlename', 'gender', 'state','age',  'date_of_birth',
       'report_year',  'disease']]

# %%
meningitis1.head()
# Out:
#    id    surname  firstname middlename  gender   state  age date_of_birth  \
# 0   1     Solade      Grace     Solape  Female  Rivers   32    1986-01-17
# 1   2     Eneche       Kure    Balogun    Male  Ebonyi   32    1985-09-01
# 2   3     Sanusi     Adaugo   Katerine  Female    Ogun   24    1988-05-01
# 3   4     Sowore  Mooslemat    Ifedayo  Female    Ondo   63    1947-05-24
# 4   5  Abdusalam      Yusuf     Okafor    Male     Oyo    9    2008-01-07
#
#    report_year        disease
# 0         2018        Cholera
# 1         2017  Marburg Virus
# 2         2012  Marburg Virus
# 3         2010        Measles
# 4         2017   Rubella Mars

# %%
meningitis.loc[:, ['id', 'surname', 'firstname', 'middlename', 'gender', 'state','age',  'date_of_birth',
       'report_year',  'disease']]
# Out:
#             id    surname  firstname middlename  gender        state  age  \
# 0            1     Solade      Grace     Solape  Female       Rivers   32
# 1            2     Eneche       Kure    Balogun    Male       Ebonyi   32
# 2            3     Sanusi     Adaugo   Katerine  Female         Ogun   24
# 3            4     Sowore  Mooslemat    Ifedayo  Female         Ondo   63
# 4            5  Abdusalam      Yusuf     Okafor    Male          Oyo    9
# ...        ...        ...        ...        ...     ...          ...  ...
# 284479  288418    Mukthar     Alimat    Ajibewa  Female  Cross River   67
# 284480  288419    Akenzua    Deborah   Rofeeqat  Female        Kwara   64
# 284481  288420        Isa    Deborah    Tofunmi  Female      Katsina   33
# 284482  288421        Uba     Ismail    Akpabio    Male       Jigawa   18
# 284483  288422       Alao    Paulina       Sade  Female         Kogi    7
#
#        date_of_birth  report_year        disease
# ...

# %%
meningitis1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284484 entries, 0 to 284483
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             284484 non-null  int64
#  1   surname        284484 non-null  object
#  2   firstname      284484 non-null  object
#  3   middlename     284484 non-null  object
#  4   gender         284484 non-null  object
#  5   state          284484 non-null  object
#  6   age            284484 non-null  int64
#  7   date_of_birth  284484 non-null  object
#  8   report_year    284484 non-null  int64
#  9   disease        284484 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 21.7+ MB

# %%
meningitis1.isnull().sum()
# Out:
# id               0
# surname          0
# firstname        0
# middlename       0
# gender           0
# state            0
# age              0
# date_of_birth    0
# report_year      0
# disease          0
# dtype: int64

# %%
female=meningitis1.loc[meningitis1["gender"]=="Female"]

# %%
meningitis1.rename(columns={"date_of_birth":"dob"})
# Out:
#             id    surname  firstname middlename  gender        state  age  \
# 0            1     Solade      Grace     Solape  Female       Rivers   32
# 1            2     Eneche       Kure    Balogun    Male       Ebonyi   32
# 2            3     Sanusi     Adaugo   Katerine  Female         Ogun   24
# 3            4     Sowore  Mooslemat    Ifedayo  Female         Ondo   63
# 4            5  Abdusalam      Yusuf     Okafor    Male          Oyo    9
# ...        ...        ...        ...        ...     ...          ...  ...
# 284479  288418    Mukthar     Alimat    Ajibewa  Female  Cross River   67
# 284480  288419    Akenzua    Deborah   Rofeeqat  Female        Kwara   64
# 284481  288420        Isa    Deborah    Tofunmi  Female      Katsina   33
# 284482  288421        Uba     Ismail    Akpabio    Male       Jigawa   18
# 284483  288422       Alao    Paulina       Sade  Female         Kogi    7
#
#                dob  report_year        disease
# ...

# %%
#meningitis1["state"].value_counts()
#meningitis1["gender"].value_counts()
meningitis1["disease"].value_counts()
# Out:
# Cholera                       28589
# Diarrhoea                     28550
# Rubella Mars                  28539
# Malaria                       28535
# Measles                       28471
# Marburg Virus                 28430
# Yellow Fever                  28428
# Viral Haemmorrhaphic Fever    28401
# Meningitis                    28362
# Ebola                         28179
# Name: disease, dtype: int64

# %%
#cat vs cat
pd.crosstab(meningitis1["gender"],meningitis[ "disease"])
# Out:
# disease  Cholera  Diarrhoea  Ebola  Malaria  Marburg Virus  Measles  \
# gender
# Female     14673      14828  14414    14630          14714    14892
# Male       13916      13722  13765    13905          13716    13579
#
# disease  Meningitis  Rubella Mars  Viral Haemmorrhaphic Fever  Yellow Fever
# gender
# Female        14691         14888                       14766         14776
# Male          13671         13651                       13635         13652

# %%
#meningitis1[["age", "disease"]].groupby("disease").mean()
meningitis1[["age", "disease"]].groupby("disease").describe()
# Out:
#                                 age                                         \
#                               count       mean        std  min   25%   50%
# disease
# Cholera                     28589.0  34.769946  22.282278  0.0  14.0  34.0
# Diarrhoea                   28550.0  34.693310  22.382887  0.0  14.0  34.0
# Ebola                       28179.0  34.751907  22.248050  0.0  14.0  34.0
# Malaria                     28535.0  34.840091  22.187810  0.0  15.0  34.0
# Marburg Virus               28430.0  34.810798  22.323839  0.0  14.0  34.0
# Measles                     28471.0  34.868217  22.181312  0.0  14.0  34.0
# Meningitis                  28362.0  34.589980  22.174482  0.0  14.0  34.0
# Rubella Mars                28539.0  34.592347  22.190821  0.0  14.0  34.0
# Viral Haemmorrhaphic Fever  28401.0  34.710468  22.182707  0.0  14.0  34.0
# Yellow Fever                28428.0  34.696602  22.255092  0.0  14.0  34.0
#
#
#                              75%   max
# disease
# ...

# %%
meningitis1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284484 entries, 0 to 284483
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             284484 non-null  int64
#  1   surname        284484 non-null  object
#  2   firstname      284484 non-null  object
#  3   middlename     284484 non-null  object
#  4   gender         284484 non-null  object
#  5   state          284484 non-null  object
#  6   age            284484 non-null  int64
#  7   date_of_birth  284484 non-null  object
#  8   report_year    284484 non-null  int64
#  9   disease        284484 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 21.7+ MB

# %%
meningitis1.columns
# Out:
# Index(['id', 'surname', 'firstname', 'middlename', 'gender', 'state', 'age',
#        'date_of_birth', 'report_year', 'disease'],
#       dtype='object')

# %%
meningitis2=meningitis1[['id', 'surname', 'firstname', 'middlename', 'gender', 'state', 'age',
      'report_year', 'disease']]

# %%
meningitis2.isnull().sum()
# Out:
# id             0
# surname        0
# firstname      0
# middlename     0
# gender         0
# state          0
# age            0
# report_year    0
# disease        0
# dtype: int64

# %%
meningitis2['disease'].value_counts()
# Out:
# Cholera                       28589
# Diarrhoea                     28550
# Rubella Mars                  28539
# Malaria                       28535
# Measles                       28471
# Marburg Virus                 28430
# Yellow Fever                  28428
# Viral Haemmorrhaphic Fever    28401
# Meningitis                    28362
# Ebola                         28179
# Name: disease, dtype: int64

# %% [markdown]
# # meningitis1["age"].describe()

# %%
#meningitis[["age","Rubella Mars"]].corr()

# %%
#pd.read_html('https://www.cdc.gov/meningococcal/php/surveillance/index.html')

# %%
select 
       surname,firstname, gender, age,state
from   meningitis
# Out:
#   File "C:\Users\segun\AppData\Local\Temp/ipykernel_10372/3209849183.py", line 2
#     surname,firstname, gender, age,state
#     ^
# IndentationError: unexpected indent

# %%
pd.read_sql 
(SELECT 
     surname 
    ,firstname 
FROM meningitis )
# Out:
#   File "C:\Users\segun\AppData\Local\Temp/ipykernel_10372/65332986.py", line 3
#     surname
#     ^
# SyntaxError: invalid syntax
